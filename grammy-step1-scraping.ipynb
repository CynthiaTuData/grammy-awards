# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %% [markdown]
# # Scraping

# %% [markdown]
# ## Collect data for the "Big Four"
# - Source: https://totalmusicawards.com/grammy-awards-winners-archive/

# %% [markdown]
# ### Collect data for album of the year and record of the year

# %%
awards =  ["album-of-the-year",
        "record-of-the-year"]
all_noms = []
for award in awards:

    url = f"https://totalmusicawards.com/grammy-awards/{award}-winners-nominees-archive/"
    html = requests.get(url).content
    doc = BeautifulSoup(html, "html.parser")
    all_years = doc.find_all("p")
    for one_year in all_years[9:73]:
        one_nom = {}
        winner = one_year.find("strong").text
        year = re.findall(r"^\d+", winner)[0]
        musician = re.findall(r", (.+$)", winner)[0]
        work = re.findall(r"^\d+: (.*), .+$", winner)[0]

        one_nom['year'] = year
        one_nom['musician'] = musician
        one_nom['work'] = work
        one_nom['category'] = award
        one_nom['status'] = 'winner'
        all_noms.append(one_nom)

        noms = one_year.find_all('br')
        for nom in noms:
            one_nom = {}
            nominee = nom.next.strip()
            musician = re.findall(r"^.+, (.+$)", nominee)
            work = re.findall(r"(.+), .+$", nominee)
            if len(musician)==1: 
                one_nom['year'] = year
                one_nom['musician'] = musician[0]
                one_nom['work'] = work[0]
                one_nom['category'] = award
                one_nom['status'] = 'nominee'
                all_noms.append(one_nom)
            else:
                typo_row =  {'year': '1980',
                              'musician': 'Supertramp',
                              'work': 'Breakfast in America',
                              'category': award,
                              'status': 'nominee'}
                all_noms.append(typo_row)

# %%
first_df = pd.DataFrame.from_dict(all_noms)
first_df.head(2)
# Out:
#    year                  musician           work           category   status
# 0  2022               Jon Batiste         We Are  album-of-the-year   winner
# 1  2022  Tony Bennett & Lady Gaga  Love for Sale  album-of-the-year  nominee

# %% [markdown]
# ### Collect data for best new artist

# %%
award = "best-new-artist"
artist_noms = []

url = f"https://totalmusicawards.com/grammy-awards/{award}-winners-nominees-archive/"
html = requests.get(url).content
doc = BeautifulSoup(html, "html.parser")
all_years = doc.find_all("p")

# %%
for one_year in all_years[3:66]:
    one_nom = {}
    winner = one_year.find("strong").text
    year = re.findall(r"(\d+): .*$", winner)[0]
    musician = re.findall(r"\d+: (.*$)", winner)[0]

    one_nom['year'] = year
    one_nom['musician'] = musician
    one_nom['work'] = 'NA'
    one_nom['category'] = award
    one_nom['status'] = 'winner'
    artist_noms.append(one_nom)

    noms = one_year.find_all('br')
    for nom in noms:
        one_nom = {}
        nominee = nom.next.strip()

        one_nom['year'] = year
        one_nom['musician'] = nominee
        one_nom['work'] = 'NA'
        one_nom['category'] = award
        one_nom['status'] = 'nominee'
        artist_noms.append(one_nom)

# %%
second_df = pd.DataFrame.from_dict(artist_noms)
second_df.head(2)
# Out:
#    year        musician work         category   status
# 0  2022  Olivia Rodrigo   NA  best-new-artist   winner
# 1  2022     Arooj Aftab   NA  best-new-artist  nominee

# %% [markdown]
# ## Collect 2023 grammys nominations

# %%
df_2023 = pd.read_csv("2023-grammy.csv")
df_2023.head(2)
# Out:
#    year musician                work            category   status
# 0  2023    Lizzo     About Damn Time  record-of-the-year   winner
# 1  2023     Abba  Don't Shut Me Down  record-of-the-year  nominee

# %%
df = pd.concat([first_df, second_df, df_2023], ignore_index=True)
df.sample(10)
# Out:
#      year        musician                             work  \
# 588  1975      Elton John  Don’t Let the Sun Go Down on Me
# 41   2017   Justin Bieber                          Purpose
# 748  2010            MGMT                               NA
# 811  1997     LeAnn Rimes                               NA
# 359  2020          Khalid                             Talk
# 195  1986    Dire Straits                 Brothers in Arms
# 126  2000    Dixie Chicks                              Fly
# 803  1999  Andrea Bocelli                               NA
# 807  1998     Fiona Apple                               NA
# 551  1983        Vangelis                 Chariots of Fire
#
#                category   status
# 588  record-of-the-year  nominee
# 41    album-of-the-year  nominee
# 748     best-new-artist  nominee
# 811     best-new-artist   winner
# 359  record-of-the-year  nominee
# 195   album-of-the-year  nominee
# 126   album-of-the-year  nominee
# 803     best-new-artist  nominee
# 807     best-new-artist  nominee
# 551  record-of-the-year  nominee

# %%
df["cleaned_musician"] = df['musician'].str.replace('[^\w\s]','')
df.sample(10)
# Out:
# /var/folders/0h/2v5mxpvs49s0_gs3lqjt474h0000gn/T/ipykernel_97842/1059051213.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["cleaned_musician"] = df['musician'].str.replace('[^\w\s]','')
#      year            musician                        work            category  \
# 582  1976  Captain & Tennille  Love Will Keep Us Together  record-of-the-year
# 66   2012           Lady Gaga               Born This Way   album-of-the-year
# 807  1998         Fiona Apple                          NA     best-new-artist
# 456  2002               Train  Drops of Jupiter (Tell Me)  record-of-the-year
# 972  1965     Astrud Gilberto                          NA     best-new-artist
# 797  2000           Macy Gray                          NA     best-new-artist
# 937  1972         Carly Simon                          NA     best-new-artist
# 784  2003       Avril Lavigne                          NA     best-new-artist
# 487  1995         Sheryl Crow              All I Wanna Do  record-of-the-year
# 481  1997   Smashing Pumpkins                        1979  record-of-the-year
#
#       status   cleaned_musician
# 582   winner  Captain  Tennille
# 66   nominee          Lady Gaga
# 807  nominee        Fiona Apple
# 456  nominee              Train
# 972  nominee    Astrud Gilberto
# 797  nominee          Macy Gray
# 937   winner        Carly Simon
# 784  nominee      Avril Lavigne
# 487   winner        Sheryl Crow
# 481  nominee  Smashing Pumpkins

# %%
df.to_csv("all-three-awards.csv",index=False)

# %%
df.year = df.year.astype(int)

# %%
df.dtypes
# Out:
# year                 int64
# musician            object
# work                object
# category            object
# status              object
# cleaned_musician    object
# dtype: object

# %% [markdown]
# For this project, I only did analysis on all nominations from 1990 to 2023.

# %%
since_1990 = df[df.year>1989]
unique = since_1990.cleaned_musician.unique().tolist()
unique
# Out:
# ['Jon Batiste',
#  'Tony Bennett  Lady Gaga',
#  'Justin Bieber',
#  'Doja Cat',
#  'Billie Eilish',
#  'HER',
#  'Lil Nas X',
#  'Olivia Rodrigo',
#  'Taylor Swift',
#  'Kanye West',
#  'Jhene Aiko',
#  'Black Pumas',
#  'Coldplay',
#  'Jacob Collier',
#  'Haim',
#  'Dua Lipa',
#  'Post Malone',
#  'Where Do We Go Billie Eilish',
#  'Bon Iver',
#  'Lana Del Rey',
#  'Ariana Grande',
#  'Lizzo',
#  'Vampire Weekend',
#  'Kacey Musgraves',
#  'Cardi B',
#  'Brandi Carlile',
#  'Drake',
#  'Kendrick Lamar  others',
#  'Janelle Monae',
#  'Bruno Mars',
#  'Childish Gambino',
#  'JayZ',
#  'Kendrick Lamar',
#  'Lorde',
#  'Adele',
#  'Beyonce',
#  'Sturgill Simpson',
#  'Alabama Shakes',
#  'Chris Stapleton',
#  'the Weeknd',
#  'Beck',
#  'Pharrell Williams',
#  'Sam Smith',
#  'Ed Sheeran',
#  'Daft Punk',
#  'Sara Bareilles',
#  'Macklemore  Ryan Lewis',
#  'Mumford  Sons',
#  'Black Keys',
#  'Frank Ocean',
#  'fun',
#  'Jack White',
#  'Foo Fighters',
#  'Lady Gaga',
#  'Rihanna',
#  'Arcade Fire',
#  'Eminem',
#  'Lady Antebellum',
#  'Katy Perry',
#  'Black Eyed Peas',
#  'Dave Matthews Band',
#  'Robert Plant  Alison Krauss',
#  'NeYo',
#  'Radiohead',
#  'Lil Wayne',
#  'Herbie Hancock',
#  'Vince Gill',
#  'Amy Winehouse',
#  'Dixie Chicks',
#  'Gnarls Barkley',
#  'John Mayer',
#  'Red Hot Chili Peppers',
#  'Justin Timberlake',
#  'U2',
#  'Mariah Carey',
#  'Paul McCartney',
#  'Gwen Stefani',
#  'Ray Charles',
#  'Green Day',
#  'Alicia Keys',
#  'Usher',
#  'Outkast',
#  'Missy Elliott',
#  'Evanescence',
#  'White Stripes',
#  'Norah Jones',
#  'Nelly',
#  'Bruce Springsteen',
#  'Where Art Thou soundtrack',
#  'IndiaArie',
#  'Bob Dylan',
#  'Steely Dan',
#  'Paul Simon',
#  'Santana',
#  'Backstreet Boys',
#  'Diana Krall',
#  'TLC',
#  'Lauryn Hill',
#  'Madonna',
#  'Sheryl Crow',
#  'Garbage',
#  'Shania Twain',
#  'Babyface',
#  'Paula Cole',
#  'Celine Dion',
#  'Fugees',
#  'Smashing Pumpkins',
#  'soundtrack',
#  'Alanis Morissette',
#  'Michael Jackson',
#  'Joan Osborne',
#  'Pearl Jam',
#  'Tony Bennett',
#  'Zubin Mehta',
#  'Eric Clapton',
#  'Bonnie Raitt',
#  'Seal',
#  'Whitney Houston',
#  'Donald Fagen',
#  'Billy Joel',
#  'REM',
#  'Sting',
#  'kd lang',
#  'Annie Lennox',
#  'Natalie Cole',
#  'Amy Grant',
#  'Quincy Jones',
#  'Phil Collins',
#  'MC Hammer',
#  'Wilson Phillips',
#  'Don Henley',
#  'Fine Young Cannibals',
#  'Tom Petty',
#  'Traveling Wilburys',
#  'Silk Sonic',
#  'Abba',
#  'Justin Bieber featuring Daniel Caesar  Giveon',
#  'Doja Cat featuring SZA',
#  'DaBaby featuring Roddy Ricch',
#  'Megan Thee Stallion featuring Beyonce',
#  'Khalid',
#  'Lil Nas X featuring Billy Ray Cyrus',
#  'Post Malone  Swae Lee',
#  'Bad Bunny  J Balvin',
#  'Lady Gaga  Bradley Cooper',
#  'Kendrick Lamar  SZA',
#  'Post Malone featuring 21 Savage',
#  'Maren Morris  Grey',
#  'Luis Fonsi  Daddy Yankee featuring Justin Bieber',
#  'Lukas Graham',
#  'Rihanna featuring Drake',
#  'Twenty One Pilots',
#  'Mark Ronson featuring Bruno Mars',
#  'DAngelo',
#  'Iggy Azalea featuring Charli XCX',
#  'Meghan Trainor',
#  'Sia',
#  'Daft Punk featuring Pharrell Williams  Nile Rodgers',
#  'Imagine Dragons',
#  'Robin Thicke featuring TI  Pharrell Williams',
#  'Gotye featuring Kimbra',
#  'Kelly Clarkson',
#  'fun featuring Janelle Monae',
#  'BoB featuring Bruno Mars',
#  'Eminem featuring Rihanna',
#  'Cee Lo Green',
#  'JayZ featuring Alicia Keys',
#  'Kings of Leon',
#  'Alison Krauss  Robert Plant',
#  'Leona Lewis',
#  'MIA',
#  'Rihanna featuring JayZ',
#  'Mary J Blige',
#  'James Blunt',
#  'Corinne Bailey Rae',
#  'Gorillaz',
#  'Ray Charles and Norah Jones',
#  'Los Lonely Boys',
#  'Usher featuring Lil Jon  Ludacris',
#  'Beyonce  JayZ',
#  'Black Eyed Peas  Justin Timberlake',
#  'Vanessa Carlton',
#  'Nelly  Kelly Rowland',
#  'Nickelback',
#  'Train',
#  'Destinys Child',
#  'Macy Gray',
#  'N Sync',
#  'Santana featuring Rob Thomas',
#  'Cher',
#  'Ricky Martin',
#  'Brandy  Monica',
#  'Goo Goo Dolls',
#  'Shawn Colvin',
#  'Hanson',
#  'R Kelly',
#  'Tracy Chapman',
#  'Mariah Carey  Boyz II Men',
#  'Coolio featuring LV',
#  'Boyz II Men',
#  'Mary Chapin Carpenter',
#  'Peabo Bryson  Regina Belle',
#  'Neil Young',
#  'Billy Ray Cyrus',
#  'Celine Dion  Peabo Bryson',
#  'Vanessa Williams',
#  'Natalie Cole with Nat King Cole',
#  'Bryan Adams',
#  'Bette Midler',
#  'Sinead OConnor',
#  'Mike  the Mechanics',
#  'Arooj Aftab',
#  'Jimmie Allen',
#  'Baby Keem',
#  'Finneas',
#  'Glass Animals',
#  'Japanese Breakfast',
#  'The Kid Laroi',
#  'Arlo Parks',
#  'Saweetie',
#  'Megan Thee Stallion',
#  'Ingrid Andress',
#  'Phoebe Bridgers',
#  'Chika',
#  'Noah Cyrus',
#  'D Smoke',
#  'Kaytranada',
#  'Maggie Rogers',
#  'Rosalia',
#  'Tank and the Bangas',
#  'Yola',
#  'Chloe x Halle',
#  'Luke Combs',
#  'Greta Van Fleet',
#  'Margo Price',
#  'Bebe Rexha',
#  'Jorja Smith',
#  'Alessia Cara',
#  'Lil Uzi Vert',
#  'Julia Michaels',
#  'SZA',
#  'Chance the Rapper',
#  'Kelsea Ballerini',
#  'Chainsmokers',
#  'Maren Morris',
#  'AndersonPaak',
#  'Courtney Barnett',
#  'James Bay',
#  'Sam Hunt',
#  'Tori Kelly',
#  'Iggy Azalea',
#  'Bastille',
#  'Brandy Clark',
#  'James Blake',
#  'Hunter Hayes',
#  'Lumineers',
#  'The Band Perry',
#  'J Cole',
#  'Nicki Minaj',
#  'Skrillex',
#  'Esperanza Spalding',
#  'Florence  the Machine',
#  'Zac Brown Band',
#  'Keri Hilson',
#  'MGMT',
#  'Silversun Pickups',
#  'The Ting Tings',
#  'Duffy',
#  'Jonas Brothers',
#  'Jazmine Sullivan',
#  'Feist',
#  'Ledisi',
#  'Paramore',
#  'Carrie Underwood',
#  'Chris Brown',
#  'Imogen Heap',
#  'John Legend',
#  'Ciara',
#  'Fall Out Boy',
#  'Keane',
#  'Sugarland',
#  'Maroon 5',
#  'Joss Stone',
#  'Gretchen Wilson',
#  '50 Cent',
#  'Fountains of Wayne',
#  'Heather Headley',
#  'Sean Paul',
#  'Ashanti',
#  'Michelle Branch',
#  'Avril Lavigne',
#  'Nelly Furtado',
#  'David Gray',
#  'Linkin Park',
#  'Shelby Lynne',
#  'Brad Paisley',
#  'Papa Roach',
#  'Jill Scott',
#  'Sisqo',
#  'Christina Aguilera',
#  'Kid Rock',
#  'Britney Spears',
#  'Susan Tedeschi',
#  'Andrea Bocelli',
#  'Natalie Imbruglia',
#  'Fiona Apple',
#  'Erykah Badu',
#  'Puff Daddy',
#  'LeAnn Rimes',
#  'Jewel',
#  'No Doubt',
#  'The Tony Rich Project',
#  'Hootie  the Blowfish',
#  'Brandy',
#  'Ace of Base',
#  'Counting Crows',
#  'Crash Test Dummies',
#  'Toni Braxton',
#  'Belly',
#  'Blind Melon',
#  'Digable Planets',
#  'SWV',
#  'Arrested Development',
#  'Sophie B Hawkins',
#  'Kris Kross',
#  'Jon Secada',
#  'Marc Cohn',
#  'CC Music Factory',
#  'Color Me Badd',
#  'Black Crowes',
#  'Kentucky Headhunters',
#  'Lisa Stansfield',
#  'Milli Vanilli award later revoked and vacated',
#  'Neneh Cherry',
#  'Indigo Girls',
#  'Soul II Soul',
#  'Tone Loc',
#  'Brandi Carlile Featuring Lucius',
#  'Steve Lacy',
#  'Harry Styles',
#  'Bad Bunny',
#  'Samara Joy',
#  'Anitta',
#  'Omar Apollo',
#  'DOMi  JD Beck',
#  'Muni Long',
#  'Latto',
#  'Måneskin',
#  'Tobe Nwigwe',
#  'Molly Tuttle',
#  'Wet Leg']

# %%
# Create a separate csv of unique musician name for cross reference 
artist = pd.DataFrame(unique, columns = ['musician'])
artist
# Out:
#                     musician
# 0                Jon Batiste
# 1    Tony Bennett  Lady Gaga
# 2              Justin Bieber
# 3                   Doja Cat
# 4              Billie Eilish
# ..                       ...
# 346                    Latto
# 347                 Måneskin
# 348              Tobe Nwigwe
# 349             Molly Tuttle
# 350                  Wet Leg
#
# [351 rows x 1 columns]

# %%
artist.to_csv("ethnicity-match.csv", index=False)
