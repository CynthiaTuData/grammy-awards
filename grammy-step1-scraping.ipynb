# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %% [markdown]
# # Scraping

# %% [markdown]
# ## Collect data for the "Big Four"
# - Source: https://totalmusicawards.com/grammy-awards-winners-archive/

# %% [markdown]
# ### Collect data for album of the year and record of the year

# %%
awards =  ["album-of-the-year",
        "record-of-the-year"]
all_noms = []
for award in awards:

    url = f"https://totalmusicawards.com/grammy-awards/{award}-winners-nominees-archive/"
    html = requests.get(url).content
    doc = BeautifulSoup(html, "html.parser")
    all_years = doc.find_all("p")
    for one_year in all_years[9:73]:
        one_nom = {}
        winner = one_year.find("strong").text
        year = re.findall(r"^\d+", winner)[0]
        musician = re.findall(r", (.+$)", winner)[0]
        work = re.findall(r"^\d+: (.*), .+$", winner)[0]

        one_nom['year'] = year
        one_nom['musician'] = musician
        one_nom['work'] = work
        one_nom['category'] = award
        one_nom['status'] = 'winner'
        all_noms.append(one_nom)

        noms = one_year.find_all('br')
        for nom in noms:
            one_nom = {}
            nominee = nom.next.strip()
            musician = re.findall(r"^.+, (.+$)", nominee)
            work = re.findall(r"(.+), .+$", nominee)
            if len(musician)==1: 
                one_nom['year'] = year
                one_nom['musician'] = musician[0]
                one_nom['work'] = work[0]
                one_nom['category'] = award
                one_nom['status'] = 'nominee'
                all_noms.append(one_nom)
            else:
                typo_row =  {'year': '1980',
                              'musician': 'Supertramp',
                              'work': 'Breakfast in America',
                              'category': award,
                              'status': 'nominee'}
                all_noms.append(typo_row)

# %%
first_df = pd.DataFrame.from_dict(all_noms)
first_df
# Out:
#      year                  musician  \
# 0    2022               Jon Batiste
# 1    2022  Tony Bennett & Lady Gaga
# 2    2022             Justin Bieber
# 3    2022                  Doja Cat
# 4    2022             Billie Eilish
# ..    ...                       ...
# 667  1959          Domenico Modugno
# 668  1959                Perry Como
# 669  1959             David Seville
# 670  1959                 Peggy Lee
# 671  1959             Frank Sinatra
#
#                                             work            category   status
# 0                                         We Are   album-of-the-year   winner
# 1                                  Love for Sale   album-of-the-year  nominee
# 2                                        Justice   album-of-the-year  nominee
# 3                                     Planet Her   album-of-the-year  nominee
# 4                              Happier Than Ever   album-of-the-year  nominee
# ..                                           ...                 ...      ...
# 667              Nel Blu Dipinto Di Blu (Volare)  record-of-the-year   winner
# 668                         Catch a Falling Star  record-of-the-year  nominee
# 669  The Chipmunk Song (Christmas Don’t Be Late)  record-of-the-year  nominee
# 670                                        Fever  record-of-the-year  nominee
# 671                                   Witchcraft  record-of-the-year  nominee
#
# [672 rows x 5 columns]

# %% [markdown]
# ### Collect data for best new artist

# %%
award = "best-new-artist"
artist_noms = []

url = f"https://totalmusicawards.com/grammy-awards/{award}-winners-nominees-archive/"
html = requests.get(url).content
doc = BeautifulSoup(html, "html.parser")
all_years = doc.find_all("p")

# %%
for one_year in all_years[3:66]:
    one_nom = {}
    winner = one_year.find("strong").text
    year = re.findall(r"(\d+): .*$", winner)[0]
    musician = re.findall(r"\d+: (.*$)", winner)[0]

    one_nom['year'] = year
    one_nom['musician'] = musician
    one_nom['work'] = 'NA'
    one_nom['category'] = award
    one_nom['status'] = 'winner'
    artist_noms.append(one_nom)

    noms = one_year.find_all('br')
    for nom in noms:
        one_nom = {}
        nominee = nom.next.strip()

        one_nom['year'] = year
        one_nom['musician'] = nominee
        one_nom['work'] = 'NA'
        one_nom['category'] = award
        one_nom['status'] = 'nominee'
        artist_noms.append(one_nom)

# %%
second_df = pd.DataFrame.from_dict(artist_noms)
second_df
# Out:
#      year        musician work         category   status
# 0    2022  Olivia Rodrigo   NA  best-new-artist   winner
# 1    2022     Arooj Aftab   NA  best-new-artist  nominee
# 2    2022    Jimmie Allen   NA  best-new-artist  nominee
# 3    2022       Baby Keem   NA  best-new-artist  nominee
# 4    2022         Finneas   NA  best-new-artist  nominee
# ..    ...             ...  ...              ...      ...
# 324  1960     Bobby Darin   NA  best-new-artist   winner
# 325  1960      Edd Byrnes   NA  best-new-artist  nominee
# 326  1960     Mark Murphy   NA  best-new-artist  nominee
# 327  1960  Johnny Restivo   NA  best-new-artist  nominee
# 328  1960    Mavis Rivers   NA  best-new-artist  nominee
#
# [329 rows x 5 columns]

# %%
df_2023 = pd.read_csv("2023-grammy.csv")
df_2023
# Out:
#     year                         musician                           work  \
# 0   2023                            Lizzo                About Damn Time
# 1   2023                             Abba             Don't Shut Me Down
# 2   2023                            Adele                     Easy On Me
# 3   2023                          Beyonce                  BREAK MY SOUL
# 4   2023                    Mary J. Blige          Good Morning Gorgeous
# 5   2023  Brandi Carlile Featuring Lucius         You And Me On The Rock
# 6   2023                         Doja Cat                          Woman
# 7   2023                       Steve Lacy                      Bad Habit
# 8   2023                     Harry Styles                      As It Was
# 9   2023                   Kendrick Lamar               The Heart Part 5
# 10  2023                     Harry Styles                  Harry's House
# 11  2023                             Abba                         Voyage
# 12  2023                            Adele                             30
# 13  2023                        Bad Bunny               Un Verano Sin Ti
# 14  2023                          Beyonce                    RENAISSANCE
# 15  2023                    Mary J. Blige          Good Morning Gorgeous
# 16  2023                   Brandi Carlile           In These Silent Days
# 17  2023                         Coldplay           Music Of The Spheres
# 18  2023                   Kendrick Lamar  Mr. Morale & The Big Steppers
# 19  2023                            Lizzo                        Special
# 20  2023                       Samara Joy                            NaN
# 21  2023                           Anitta                            NaN
# 22  2023                      Omar Apollo                            NaN
# 23  2023                   DOMi & JD Beck                            NaN
# 24  2023                        Muni Long                            NaN
# 25  2023                            Latto                            NaN
# 26  2023                         Måneskin                            NaN
# 27  2023                      Tobe Nwigwe                            NaN
# 28  2023                     Molly Tuttle                            NaN
# 29  2023                          Wet Leg                            NaN
#
#               category   status
# 0   record-of-the-year   winner
# 1   record-of-the-year  nominee
# 2   record-of-the-year  nominee
# 3   record-of-the-year  nominee
# 4   record-of-the-year  nominee
# 5   record-of-the-year  nominee
# 6   record-of-the-year  nominee
# 7   record-of-the-year  nominee
# 8   record-of-the-year  nominee
# 9   record-of-the-year  nominee
# 10   album-of-the-year   winner
# 11   album-of-the-year  nominee
# 12   album-of-the-year  nominee
# 13   album-of-the-year  nominee
# 14   album-of-the-year  nominee
# 15   album-of-the-year  nominee
# 16   album-of-the-year  nominee
# 17   album-of-the-year  nominee
# 18   album-of-the-year  nominee
# 19   album-of-the-year  nominee
# 20     best-new-artist   winner
# 21     best-new-artist  nominee
# 22     best-new-artist  nominee
# 23     best-new-artist  nominee
# 24     best-new-artist  nominee
# 25     best-new-artist  nominee
# 26     best-new-artist  nominee
# 27     best-new-artist  nominee
# 28     best-new-artist  nominee
# 29     best-new-artist  nominee

# %%
df = pd.concat([first_df, second_df, df_2023], ignore_index=True)
df.sample(10)
# Out:
#      year              musician                                 work  \
# 860  1988      Swing Out Sister                                   NA
# 50   2015               Beyonce                              Beyonce
# 877  1984           Big Country                                   NA
# 644  1964      Barbra Streisand            Happy Days Are Here Again
# 364  2019  Bad Bunny & J Balvin                   I Like It, Cardi B
# 835  1993            Jon Secada                                   NA
# 78   2010    Dave Matthews Band    Big Whiskey and the GrooGrux King
# 71   2011       Lady Antebellum                         Need You Now
# 397  2013            Black Keys                           Lonely Boy
# 321  1961           Bob Newhart  The Button-Down Mind of Bob Newhart
#
#                category   status
# 860     best-new-artist  nominee
# 50    album-of-the-year  nominee
# 877     best-new-artist  nominee
# 644  record-of-the-year  nominee
# 364  record-of-the-year  nominee
# 835     best-new-artist  nominee
# 78    album-of-the-year  nominee
# 71    album-of-the-year  nominee
# 397  record-of-the-year  nominee
# 321   album-of-the-year   winner

# %%
df["cleaned_musician"] = df['musician'].str.replace('[^\w\s]','')
df.sample(10)
# Out:
# /var/folders/0h/2v5mxpvs49s0_gs3lqjt474h0000gn/T/ipykernel_32342/1059051213.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["cleaned_musician"] = df['musician'].str.replace('[^\w\s]','')
#      year                 musician                           work  \
# 533  1986             Dire Straits              Money for Nothing
# 977  1964                John Gary                             NA
# 435  2006             Gwen Stefani                 Hollaback Girl
# 426  2008        Justin Timberlake  What Goes Around…Comes Around
# 506  1992                   R.E.M.             Losing My Religion
# 512  1990             Bette Midler          Wind Beneath My Wings
# 737  2012           The Band Perry                             NA
# 681  2022                 Saweetie                             NA
# 436  2006               Kanye West                    Gold Digger
# 57   2014  Macklemore & Ryan Lewis                      The Heist
#
#                category   status        cleaned_musician
# 533  record-of-the-year  nominee            Dire Straits
# 977     best-new-artist  nominee               John Gary
# 435  record-of-the-year  nominee            Gwen Stefani
# 426  record-of-the-year  nominee       Justin Timberlake
# 506  record-of-the-year  nominee                     REM
# 512  record-of-the-year   winner            Bette Midler
# 737     best-new-artist  nominee          The Band Perry
# 681     best-new-artist  nominee                Saweetie
# 436  record-of-the-year  nominee              Kanye West
# 57    album-of-the-year  nominee  Macklemore  Ryan Lewis

# %%
df.to_csv("all-three-awards.csv",index=False)

# %%
df.year = df.year.astype(int)

# %%
df.dtypes
# Out:
# year                 int64
# musician            object
# work                object
# category            object
# status              object
# cleaned_musician    object
# dtype: object

# %%
since_1990 = df[df.year>1989]
unique = since_1990.cleaned_musician.unique().tolist()
unique
# Out:
# ['Jon Batiste',
#  'Tony Bennett  Lady Gaga',
#  'Justin Bieber',
#  'Doja Cat',
#  'Billie Eilish',
#  'HER',
#  'Lil Nas X',
#  'Olivia Rodrigo',
#  'Taylor Swift',
#  'Kanye West',
#  'Jhene Aiko',
#  'Black Pumas',
#  'Coldplay',
#  'Jacob Collier',
#  'Haim',
#  'Dua Lipa',
#  'Post Malone',
#  'Where Do We Go Billie Eilish',
#  'Bon Iver',
#  'Lana Del Rey',
#  'Ariana Grande',
#  'Lizzo',
#  'Vampire Weekend',
#  'Kacey Musgraves',
#  'Cardi B',
#  'Brandi Carlile',
#  'Drake',
#  'Kendrick Lamar  others',
#  'Janelle Monae',
#  'Bruno Mars',
#  'Childish Gambino',
#  'JayZ',
#  'Kendrick Lamar',
#  'Lorde',
#  'Adele',
#  'Beyonce',
#  'Sturgill Simpson',
#  'Alabama Shakes',
#  'Chris Stapleton',
#  'the Weeknd',
#  'Beck',
#  'Pharrell Williams',
#  'Sam Smith',
#  'Ed Sheeran',
#  'Daft Punk',
#  'Sara Bareilles',
#  'Macklemore  Ryan Lewis',
#  'Mumford  Sons',
#  'Black Keys',
#  'Frank Ocean',
#  'fun',
#  'Jack White',
#  'Foo Fighters',
#  'Lady Gaga',
#  'Rihanna',
#  'Arcade Fire',
#  'Eminem',
#  'Lady Antebellum',
#  'Katy Perry',
#  'Black Eyed Peas',
#  'Dave Matthews Band',
#  'Robert Plant  Alison Krauss',
#  'NeYo',
#  'Radiohead',
#  'Lil Wayne',
#  'Herbie Hancock',
#  'Vince Gill',
#  'Amy Winehouse',
#  'Dixie Chicks',
#  'Gnarls Barkley',
#  'John Mayer',
#  'Red Hot Chili Peppers',
#  'Justin Timberlake',
#  'U2',
#  'Mariah Carey',
#  'Paul McCartney',
#  'Gwen Stefani',
#  'Ray Charles',
#  'Green Day',
#  'Alicia Keys',
#  'Usher',
#  'Outkast',
#  'Missy Elliott',
#  'Evanescence',
#  'White Stripes',
#  'Norah Jones',
#  'Nelly',
#  'Bruce Springsteen',
#  'Where Art Thou soundtrack',
#  'IndiaArie',
#  'Bob Dylan',
#  'Steely Dan',
#  'Paul Simon',
#  'Santana',
#  'Backstreet Boys',
#  'Diana Krall',
#  'TLC',
#  'Lauryn Hill',
#  'Madonna',
#  'Sheryl Crow',
#  'Garbage',
#  'Shania Twain',
#  'Babyface',
#  'Paula Cole',
#  'Celine Dion',
#  'Fugees',
#  'Smashing Pumpkins',
#  'soundtrack',
#  'Alanis Morissette',
#  'Michael Jackson',
#  'Joan Osborne',
#  'Pearl Jam',
#  'Tony Bennett',
#  'Zubin Mehta',
#  'Eric Clapton',
#  'Bonnie Raitt',
#  'Seal',
#  'Whitney Houston',
#  'Donald Fagen',
#  'Billy Joel',
#  'REM',
#  'Sting',
#  'kd lang',
#  'Annie Lennox',
#  'Natalie Cole',
#  'Amy Grant',
#  'Quincy Jones',
#  'Phil Collins',
#  'MC Hammer',
#  'Wilson Phillips',
#  'Don Henley',
#  'Fine Young Cannibals',
#  'Tom Petty',
#  'Traveling Wilburys',
#  'Silk Sonic',
#  'Abba',
#  'Justin Bieber featuring Daniel Caesar  Giveon',
#  'Doja Cat featuring SZA',
#  'DaBaby featuring Roddy Ricch',
#  'Megan Thee Stallion featuring Beyonce',
#  'Khalid',
#  'Lil Nas X featuring Billy Ray Cyrus',
#  'Post Malone  Swae Lee',
#  'Bad Bunny  J Balvin',
#  'Lady Gaga  Bradley Cooper',
#  'Kendrick Lamar  SZA',
#  'Post Malone featuring 21 Savage',
#  'Maren Morris  Grey',
#  'Luis Fonsi  Daddy Yankee featuring Justin Bieber',
#  'Lukas Graham',
#  'Rihanna featuring Drake',
#  'Twenty One Pilots',
#  'Mark Ronson featuring Bruno Mars',
#  'DAngelo',
#  'Iggy Azalea featuring Charli XCX',
#  'Meghan Trainor',
#  'Sia',
#  'Daft Punk featuring Pharrell Williams  Nile Rodgers',
#  'Imagine Dragons',
#  'Robin Thicke featuring TI  Pharrell Williams',
#  'Gotye featuring Kimbra',
#  'Kelly Clarkson',
#  'fun featuring Janelle Monae',
#  'BoB featuring Bruno Mars',
#  'Eminem featuring Rihanna',
#  'Cee Lo Green',
#  'JayZ featuring Alicia Keys',
#  'Kings of Leon',
#  'Alison Krauss  Robert Plant',
#  'Leona Lewis',
#  'MIA',
#  'Rihanna featuring JayZ',
#  'Mary J Blige',
#  'James Blunt',
#  'Corinne Bailey Rae',
#  'Gorillaz',
#  'Ray Charles and Norah Jones',
#  'Los Lonely Boys',
#  'Usher featuring Lil Jon  Ludacris',
#  'Beyonce  JayZ',
#  'Black Eyed Peas  Justin Timberlake',
#  'Vanessa Carlton',
#  'Nelly  Kelly Rowland',
#  'Nickelback',
#  'Train',
#  'Destinys Child',
#  'Macy Gray',
#  'N Sync',
#  'Santana featuring Rob Thomas',
#  'Cher',
#  'Ricky Martin',
#  'Brandy  Monica',
#  'Goo Goo Dolls',
#  'Shawn Colvin',
#  'Hanson',
#  'R Kelly',
#  'Tracy Chapman',
#  'Mariah Carey  Boyz II Men',
#  'Coolio featuring LV',
#  'Boyz II Men',
#  'Mary Chapin Carpenter',
#  'Peabo Bryson  Regina Belle',
#  'Neil Young',
#  'Billy Ray Cyrus',
#  'Celine Dion  Peabo Bryson',
#  'Vanessa Williams',
#  'Natalie Cole with Nat King Cole',
#  'Bryan Adams',
#  'Bette Midler',
#  'Sinead OConnor',
#  'Mike  the Mechanics',
#  'Arooj Aftab',
#  'Jimmie Allen',
#  'Baby Keem',
#  'Finneas',
#  'Glass Animals',
#  'Japanese Breakfast',
#  'The Kid Laroi',
#  'Arlo Parks',
#  'Saweetie',
#  'Megan Thee Stallion',
#  'Ingrid Andress',
#  'Phoebe Bridgers',
#  'Chika',
#  'Noah Cyrus',
#  'D Smoke',
#  'Kaytranada',
#  'Maggie Rogers',
#  'Rosalia',
#  'Tank and the Bangas',
#  'Yola',
#  'Chloe x Halle',
#  'Luke Combs',
#  'Greta Van Fleet',
#  'Margo Price',
#  'Bebe Rexha',
#  'Jorja Smith',
#  'Alessia Cara',
#  'Lil Uzi Vert',
#  'Julia Michaels',
#  'SZA',
#  'Chance the Rapper',
#  'Kelsea Ballerini',
#  'Chainsmokers',
#  'Maren Morris',
#  'AndersonPaak',
#  'Courtney Barnett',
#  'James Bay',
#  'Sam Hunt',
#  'Tori Kelly',
#  'Iggy Azalea',
#  'Bastille',
#  'Brandy Clark',
#  'James Blake',
#  'Hunter Hayes',
#  'Lumineers',
#  'The Band Perry',
#  'J Cole',
#  'Nicki Minaj',
#  'Skrillex',
#  'Esperanza Spalding',
#  'Florence  the Machine',
#  'Zac Brown Band',
#  'Keri Hilson',
#  'MGMT',
#  'Silversun Pickups',
#  'The Ting Tings',
#  'Duffy',
#  'Jonas Brothers',
#  'Jazmine Sullivan',
#  'Feist',
#  'Ledisi',
#  'Paramore',
#  'Carrie Underwood',
#  'Chris Brown',
#  'Imogen Heap',
#  'John Legend',
#  'Ciara',
#  'Fall Out Boy',
#  'Keane',
#  'Sugarland',
#  'Maroon 5',
#  'Joss Stone',
#  'Gretchen Wilson',
#  '50 Cent',
#  'Fountains of Wayne',
#  'Heather Headley',
#  'Sean Paul',
#  'Ashanti',
#  'Michelle Branch',
#  'Avril Lavigne',
#  'Nelly Furtado',
#  'David Gray',
#  'Linkin Park',
#  'Shelby Lynne',
#  'Brad Paisley',
#  'Papa Roach',
#  'Jill Scott',
#  'Sisqo',
#  'Christina Aguilera',
#  'Kid Rock',
#  'Britney Spears',
#  'Susan Tedeschi',
#  'Andrea Bocelli',
#  'Natalie Imbruglia',
#  'Fiona Apple',
#  'Erykah Badu',
#  'Puff Daddy',
#  'LeAnn Rimes',
#  'Jewel',
#  'No Doubt',
#  'The Tony Rich Project',
#  'Hootie  the Blowfish',
#  'Brandy',
#  'Ace of Base',
#  'Counting Crows',
#  'Crash Test Dummies',
#  'Toni Braxton',
#  'Belly',
#  'Blind Melon',
#  'Digable Planets',
#  'SWV',
#  'Arrested Development',
#  'Sophie B Hawkins',
#  'Kris Kross',
#  'Jon Secada',
#  'Marc Cohn',
#  'CC Music Factory',
#  'Color Me Badd',
#  'Black Crowes',
#  'Kentucky Headhunters',
#  'Lisa Stansfield',
#  'Milli Vanilli award later revoked and vacated',
#  'Neneh Cherry',
#  'Indigo Girls',
#  'Soul II Soul',
#  'Tone Loc',
#  'Brandi Carlile Featuring Lucius',
#  'Steve Lacy',
#  'Harry Styles',
#  'Bad Bunny',
#  'Samara Joy',
#  'Anitta',
#  'Omar Apollo',
#  'DOMi  JD Beck',
#  'Muni Long',
#  'Latto',
#  'Måneskin',
#  'Tobe Nwigwe',
#  'Molly Tuttle',
#  'Wet Leg']

# %%
# Create a separate csv of unique musician name for cross reference 
artist = pd.DataFrame(unique, columns = ['musician'])
artist
# Out:
#                     musician
# 0                Jon Batiste
# 1    Tony Bennett  Lady Gaga
# 2              Justin Bieber
# 3                   Doja Cat
# 4              Billie Eilish
# ..                       ...
# 346                    Latto
# 347                 Måneskin
# 348              Tobe Nwigwe
# 349             Molly Tuttle
# 350                  Wet Leg
#
# [351 rows x 1 columns]

# %%
artist.to_csv("ethnicity-match.csv", index=False)
