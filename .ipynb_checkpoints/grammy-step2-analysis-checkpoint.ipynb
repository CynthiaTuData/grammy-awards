# %%
import pandas as pd
import re

# %%
df = pd.read_csv("all-three-awards.csv")
ethnic = pd.read_csv('2022-1990-ethnicity-lookup.csv')

# %%
# Fix datatype for year column
df['year'] = df['year'].astype(int)
df.dtypes
# Out:
# year                 int64
# musician            object
# work                object
# category            object
# status              object
# cleaned_musician    object
# dtype: object

# %%
# Only select Grammys from 1990 to 2023
df = df[df.year>1989]

# %%
# merge the two dataframes together
merged = pd.merge(df, ethnic, how='left', on='cleaned_musician')
merged.head(2)
# Out:
#    year                musician_x           work           category   status  \
# 0  2022               Jon Batiste         We Are  album-of-the-year   winner
# 1  2022  Tony Bennett & Lady Gaga  Love for Sale  album-of-the-year  nominee
#
#           cleaned_musician                musician_y ethnicity shared_award  \
# 0              Jon Batiste               Jon Batiste        UR          NaN
# 1  Tony Bennett  Lady Gaga  Tony Bennett & Lady Gaga     white          NaN
#
#    Column1
# 0      NaN
# 1      NaN

# %%
# Fix NA values in ethnicity column
merged[merged.cleaned_musician=='soundtrack']
# Out:
#      year  musician_x                  work           category   status  \
# 143  1997  soundtrack     Waiting to Exhale  album-of-the-year  nominee
# 163  1993  soundtrack  Beauty and the Beast  album-of-the-year  nominee
#
#     cleaned_musician  musician_y ethnicity shared_award  Column1
# 143       soundtrack  soundtrack       NaN          NaN      NaN
# 163       soundtrack  soundtrack       NaN          NaN      NaN

# %%
# Add ethnicity info for albums with musician "soundtrack"
merged.at[143,'ethnicity']='UR'
merged.at[163,'ethnicity']='white'

# %%
# Check to see if changes have been made
merged[merged.cleaned_musician=='soundtrack']
# Out:
#      year  musician_x                  work           category   status  \
# 143  1997  soundtrack     Waiting to Exhale  album-of-the-year  nominee
# 163  1993  soundtrack  Beauty and the Beast  album-of-the-year  nominee
#
#     cleaned_musician  musician_y ethnicity shared_award  Column1
# 143       soundtrack  soundtrack        UR          NaN      NaN
# 163       soundtrack  soundtrack     white          NaN      NaN

# %%
# Add an unique ID column
merged['id'] = range(1, len(merged) + 1)
merged.head(2)
# Out:
#    year                musician_x           work           category   status  \
# 0  2022               Jon Batiste         We Are  album-of-the-year   winner
# 1  2022  Tony Bennett & Lady Gaga  Love for Sale  album-of-the-year  nominee
#
#           cleaned_musician                musician_y ethnicity shared_award  \
# 0              Jon Batiste               Jon Batiste        UR          NaN
# 1  Tony Bennett  Lady Gaga  Tony Bennett & Lady Gaga     white          NaN
#
#    Column1  id
# 0      NaN   1
# 1      NaN   2

# %% [markdown]
# ### A function to lookup award results by year

# %%
def look_up_year(i):
    df = merged[merged['year'] == i]
    return(df)

# %%
look_up_year(2013)
# Out:
#      year                    musician_x  \
# 59   2013                Mumford & Sons
# 60   2013                    Black Keys
# 61   2013                   Frank Ocean
# 62   2013                          fun.
# 63   2013                    Jack White
# 238  2013        Gotye featuring Kimbra
# 239  2013                    Black Keys
# 240  2013                Kelly Clarkson
# 241  2013  fun. featuring Janelle Monae
# 242  2013                   Frank Ocean
# 243  2013                  Taylor Swift
# 418  2013                          fun.
# 419  2013                Alabama Shakes
# 420  2013                  Hunter Hayes
# 421  2013                     Lumineers
# 422  2013                   Frank Ocean
#
#                                         work            category   status  \
# 59                                     Babel   album-of-the-year   winner
# 60                                 El Camino   album-of-the-year  nominee
# 61                            Channel Orange   album-of-the-year  nominee
# 62                               Some Nights   album-of-the-year  nominee
# 63                               Blunderbuss   album-of-the-year  nominee
# 238             Somebody That I Used to Know  record-of-the-year   winner
# 239                               Lonely Boy  record-of-the-year  nominee
# 240         Stronger (What Doesn’t Kill You)  record-of-the-year  nominee
# 241                             We Are Young  record-of-the-year  nominee
# 242                         Thinkin Bout You  record-of-the-year  nominee
# 243  We Are Never Ever Getting Back Together  record-of-the-year  nominee
# 418                                      NaN     best-new-artist   winner
# 419                                      NaN     best-new-artist  nominee
# 420                                      NaN     best-new-artist  nominee
# 421                                      NaN     best-new-artist  nominee
# 422                                      NaN     best-new-artist  nominee
#
#                 cleaned_musician                    musician_y ethnicity  \
# 59                 Mumford  Sons                Mumford & Sons     white
# 60                    Black Keys                    Black Keys     white
# 61                   Frank Ocean                   Frank Ocean        UR
# 62                           fun                          fun.     white
# 63                    Jack White                    Jack White     white
# 238       Gotye featuring Kimbra        Gotye featuring Kimbra     white
# 239                   Black Keys                    Black Keys     white
# 240               Kelly Clarkson                Kelly Clarkson     white
# 241  fun featuring Janelle Monae  fun. featuring Janelle Monae        UR
# 242                  Frank Ocean                   Frank Ocean        UR
# 243                 Taylor Swift                  Taylor Swift     white
# 418                          fun                          fun.     white
# 419               Alabama Shakes                Alabama Shakes        UR
# 420                 Hunter Hayes                  Hunter Hayes     white
# 421                    Lumineers                     Lumineers     white
# 422                  Frank Ocean                   Frank Ocean        UR
#
#     shared_award  Column1   id  total_percentage status/ethnicity
# 59           NaN      NaN   60            0.3125     white winner
# 60           NaN      NaN   61            0.3125    white nominee
# 61           NaN      NaN   62            0.3125       UR nominee
# 62           NaN      NaN   63            0.3125    white nominee
# 63           NaN      NaN   64            0.3125    white nominee
# 238          NaN      NaN  239            0.3125     white winner
# 239          NaN      NaN  240            0.3125    white nominee
# 240          NaN      NaN  241            0.3125    white nominee
# 241       shared      NaN  242            0.3125       UR nominee
# 242          NaN      NaN  243            0.3125       UR nominee
# 243          NaN      NaN  244            0.3125    white nominee
# 418          NaN      NaN  419            0.3125     white winner
# 419          NaN      NaN  420            0.3125       UR nominee
# 420          NaN      NaN  421            0.3125    white nominee
# 421          NaN      NaN  422            0.3125    white nominee
# 422          NaN      NaN  423            0.3125       UR nominee

# %% [markdown]
# ### A function that calculates the percentage of UR nominees in a spcific year

# %%
def get_total_percentage(i):
    df = merged[merged['year'] == i]
    total = df.value_counts('id').sum()
    UR_count = df[df['ethnicity'] == 'UR'].value_counts('id').sum()
    UR_percentage = UR_count/total
    return(UR_percentage)

# %%
get_total_percentage(1991)
# Out:
# 0.4

# %%
# Create a new column with percentage of UR nominees each year
merged['total_percentage'] = merged.apply(lambda x: get_total_percentage(x['year']), axis=1)
merged.head(2)
# Out:
#    year                musician_x           work           category   status  \
# 0  2022               Jon Batiste         We Are  album-of-the-year   winner
# 1  2022  Tony Bennett & Lady Gaga  Love for Sale  album-of-the-year  nominee
#
#           cleaned_musician                musician_y ethnicity shared_award  \
# 0              Jon Batiste               Jon Batiste        UR          NaN
# 1  Tony Bennett  Lady Gaga  Tony Bennett & Lady Gaga     white          NaN
#
#    Column1  id  total_percentage
# 0      NaN   1          0.666667
# 1      NaN   2          0.666667

# %% [markdown]
# ### A pivot table to see the racial makeup of nominees each year and the chance of winning

# %%
pivot = pd.pivot_table(merged, values='id', 
                            index=['category','ethnicity'], 
                            columns='status', 
                            aggfunc='count',
                            fill_value=0)
pivot['total'] = pivot['nominee']+pivot['winner']
pivot['chance'] = pivot['winner']/pivot['total']

pivot
# Out:
# status                        nominee  winner  total    chance
# category           ethnicity
# album-of-the-year  UR              63      11     74  0.148649
#                    white           92      23    115  0.200000
# best-new-artist    UR              70      13     83  0.156627
#                    white           85      21    106  0.198113
# record-of-the-year UR              79      11     90  0.122222
#                    white           76      23     99  0.232323

# %% [markdown]
# ## A function to calculate the chance of winning by race in different award category

# %%
def chance_by_award(award):
    df=merged[merged.category == award]
    pivot = pd.pivot_table(df, values='id', 
                                index='ethnicity', 
                                columns='status', 
                                aggfunc='count',
                                fill_value=0)
    pivot['total'] = pivot['nominee']+pivot['winner']
    pivot['chance'] = pivot['winner']/pivot['total']
    
    white = pivot.iloc[1].chance
    UR = pivot.iloc[0].chance
    
    ratio = white/UR
    
    return(pivot,ratio)

# %%
chance_by_award('record-of-the-year')
# Out:
# (status     nominee  winner  total    chance
#  ethnicity
#  UR              79      11     90  0.122222
#  white           76      23     99  0.232323,
#  1.9008264462809918)

# %%
def chance_by_year(year):
    df=merged[merged.year == year]
    pivot = pd.pivot_table(df, values='id', 
                                index='ethnicity', 
                                columns='status', 
                                aggfunc='count',
                                fill_value=0)
    pivot['total'] = pivot['nominee']+pivot['winner']
    pivot['chance'] = pivot['winner']/pivot['total']
    
    white = pivot.iloc[1].chance
    UR = pivot.iloc[0].chance
    
    ratio = white/UR
    return(pivot,ratio)

# %%
chance_by_year(2011)
# Out:
# /var/folders/0h/2v5mxpvs49s0_gs3lqjt474h0000gn/T/ipykernel_55696/3468669334.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#   ratio = white/UR
# (status     nominee  winner  total  chance
#  ethnicity
#  UR               5       0      5     0.0
#  white            7       3     10     0.3,
#  inf)

# %% [markdown]
# # Some rough exploratory vizs

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# require('tidyverse')
# Out:
# R[write to console]: Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ### Plot the trends of UR nominations over the years

# %%
# %%R -i merged
# ggplot(merged,aes(y=total_percentage,x=year))+geom_line()

# %% [markdown]
# ### Plot the makeup of white and non-white musicians nominated each year

# %%
# %%R -i merged
# ggplot(merged, aes(x = year, fill = ethnicity)) +
#   geom_dotplot(stackgroups = TRUE, binwidth = 1, binpositions = "all")

# %%
all_years = pd.pivot_table(merged, values='id', 
                                index='year', 
                                columns='ethnicity', 
                                aggfunc='count',
                                fill_value=0)
all_years.head()
# Out:
# ethnicity  UR  white
# year
# 1990        6      9
# 1991        6      9
# 1992        6      9
# 1993        5     10
# 1994        5     10

# %%
# %%R -i all_years
# all_years <- mutate
# ggplot(all_years, aes(x = year, y = ethnicity)) +
#   geom_dotplot(stackgroups = TRUE, binwidth = 1, binpositions = "all")
#
# ggplot(TP, aes(x = State, y = Trees)) +
#   geom_col()

# %%
merged['status/ethnicity'] = merged['ethnicity']+" "+merged['status']
merged.head(2)
# Out:
#    year                musician_x           work           category   status  \
# 0  2022               Jon Batiste         We Are  album-of-the-year   winner
# 1  2022  Tony Bennett & Lady Gaga  Love for Sale  album-of-the-year  nominee
#
#           cleaned_musician                musician_y ethnicity shared_award  \
# 0              Jon Batiste               Jon Batiste        UR          NaN
# 1  Tony Bennett  Lady Gaga  Tony Bennett & Lady Gaga     white          NaN
#
#    Column1  id  total_percentage status/ethnicity
# 0      NaN   1          0.666667        UR winner
# 1      NaN   2          0.666667    white nominee

# %% [markdown]
# ### Plot the makeup of white and non-white nominations and winner's race over the years

# %%
# %%R -i merged
#
# ggplot(merged, aes(x = year, fill = `status/ethnicity`)) +
#     scale_fill_manual(values = c("UR nominee" = "lightblue","UR winner" = "blue",'white nominee'='pink','white winner' = 'red'))+
#   geom_dotplot(stackgroups = TRUE, binwidth = 1, binpositions = "all")
